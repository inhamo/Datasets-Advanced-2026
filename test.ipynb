# %%
import pandas as pd

# %%
data = pd.read_parquet(r"C:\Users\takue\OneDrive\Documents\Datasets\banking_data\2023\04\debit_order_transactions_2023_04.parquet")
data.head()
# Out:
#       transaction_id    debit_order_id  customer_id  account_id  \
# 0  TXN20230400000001  DBT2023010000002  IND23009585  ACC0059011
# 1  TXN20230400000002  DBT2023010000003  IND23009619  ACC0057713
# 2  TXN20230400000003  DBT2023010000008  IND23020421  ACC0057577
# 3  TXN20230400000004  DBT2023010000009  IND23003307  ACC0057642
# 4  TXN20230400000005  DBT2023010000011  IND23012937  ACC0057882
#
#   transaction_date transaction_time    amount debit_credit     status  \
# 0       2023-04-24         00:20:27   1575.61        Debit  Completed
# 1       2023-04-28         17:25:03   1150.42        Debit  Completed
# 2       2023-05-02         06:27:01    101.43        Debit  Completed
# 3       2023-05-02         03:51:11    119.90        Debit  Completed
# 4       2023-05-02         06:46:01  10481.84        Debit  Completed
#
#   failure_reason                                  description    channel  \
# 0            NaN             Internal transfer - Subscription  Automated
# ...
